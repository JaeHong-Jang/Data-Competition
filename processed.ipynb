# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
def improved_preprocessing_final(df, model_type='tree'):
    """
    공모전 목표에 최적화된 최종 전처리 함수
    
    Parameters:
    -----------
    df: 원본 데이터프레임
    model_type: 'tree', 'linear', 'nn'
    
    Returns:
    --------
    X_processed: 전처리된 특징
    y: 타겟 변수
    scenario_mapping: 시나리오 정보 (분석용)
    feature_groups: 변수 그룹 정보 (공모전 요구사항)
    """
    
    # ========================================
    # STEP 1: 타겟 변수 분리
    # ========================================
    target_columns = ['Leaf_TPC', 'Root_TPC', 'Leaf_TFC', 'Root_TFC']
    y = df[target_columns].copy()
    
    # 예측 변수 (추출수율 제외 - 품질 지표 아님) -> EDA 결과 음 상관관계, 예측변수 부적절(실험 후 알 수 있는 지표) 
    X = df.drop(columns=target_columns + ['Leaf_ExtractionYield', 'Root_ExtractionYield'])
    
    # ========================================
    # STEP 2: 시나리오 정보 보존 (공모전 핵심!)
    # ========================================
    scenario_mapping = X['scenario'].copy()  # 분석용 보존
    
    # 시나리오 원핫인코딩 (dtype=int로 통일) -> SSP3 일부 지표가 SSP5보다 나쁨, 복합스트레스 효과 
    X = pd.get_dummies(X, columns=['scenario'], prefix='scenario', dtype=int)
    
    # ========================================
    # STEP 3: 생물학적 검증 및 플래그
    # ========================================
    
    # 극한 스트레스 플래그 (누락된 중요 변수!) -> 0.6이하 = 광계 2 손상 심각, 회복 어려움
    X['extreme_stress_fv'] = (X['Fv-Fm'] < 0.6).astype(int)
    
    # 에너지 보존 검증 -> OJIP 분석법 기본 원리
    X['energy_violation'] = (abs(X['ABS-RC'] - (X['Tro-RC'] + X['Dio-RC'])) > 1.0).astype(int)
    
    # ========================================
    # STEP 4: TChl 제거 (필수! 다중공선성)
    # ========================================
    if 'TChl' in X.columns:
        X = X.drop(columns=['TChl'])
        print(f"  TChl 제거 완료 (Chl_a + Chl_b와 중복)")
    
    # ========================================
    # STEP 5: Feature Engineering
    # ========================================
    
    # 5-1. 생장 단계 (dtype=int로 통일) -> 5-7월 영양생장, 8-9월 생식생장 
    growth_stage_map = {
        5: 'vegetative_early',
        6: 'vegetative_mid',
        7: 'vegetative_late',
        8: 'reproductive',
        9: 'senescence'
    }
    
    # 임시 생장 단계 변수 생성
    X['growth_stage'] = X['month'].map(growth_stage_map)
    X = pd.get_dummies(X, columns=['growth_stage'], prefix='stage', dtype=int)
    
    # 5-2. 스트레스 지표 (모두 int로 통일) -> VPD 2.5 이상 = 미세털 보호 매커니즘, 15이상 25이하 적정 온도, co2 = 800ppm 이상 독성 시작
    X['vpd_stress'] = (X['VPD'] > 2.5).astype(int)
    X['temp_optimal'] = ((X['Temp'] >= 15) & (X['Temp'] <= 25)).astype(int)
    X['heat_stress'] = (X['Temp'] > 25).astype(int)
    X['cold_stress'] = (X['Temp'] < 15).astype(int)
    X['co2_toxic'] = (X['CO2ppm'] > 800).astype(int)
    
    # 5-3. 복합 스트레스 지수 -> 온도, CO2 상호 작용 
    X['stress_index'] = (X['Temp'] - 20) * (X['CO2ppm'] - 432) / 432
    
    # 5-4. 특이 패턴 -> 6월 이상 특이패턴, 9월 전환기 = 지상부에서 지하부 자원 재분배
    X['ssp3_june_anomaly'] = ((X['scenario_SSP3'] == 1) & (X['month'] == 6)).astype(int)
    X['september_transition'] = (X['month'] == 9).astype(int)
    
    # 5-5. 에너지 효율 -> 비율로 계산 = 절대값보다 비율 생리 상태를 잘 표현 가능
    X['energy_efficiency'] = np.where(X['Tro-RC'] > 0, 
                                      X['Eto-RC'] / X['Tro-RC'], 0)
    X['dissipation_ratio'] = np.where(X['ABS-RC'] > 0,
                                      X['Dio-RC'] / X['ABS-RC'], 0)
    
    # ========================================
    # STEP 6: 변수 그룹 정의 (공모전 요구사항!)
    # ========================================
    feature_groups = {
        '환경정보': ['month', 'CO2ppm', 'Temp', 'Humid', 'VPD'],
        
        '생리반응정보': ['Chl_a', 'Chl_b', 'Car', 'Chl_a_b', 'TCh-Car'],
        
        '생리활성정보': ['ABS-RC', 'Dio-RC', 'Tro-RC', 'Eto-RC', 
                      'PI_abs', 'DF_abs', 'SFI_abs', 'Fv-Fm'],
        
        '시나리오변수': ['scenario_SSP1', 'scenario_SSP3', 'scenario_SSP5'],
        
        '생장단계': [col for col in X.columns if 'stage_' in col],
        
        '스트레스지표': ['extreme_stress_fv', 'vpd_stress', 'temp_optimal',
                      'heat_stress', 'cold_stress', 'co2_toxic',
                      'energy_violation', 'ssp3_june_anomaly',
                      'september_transition'],
        
        '복합지표': ['stress_index', 'energy_efficiency', 'dissipation_ratio']
    }
    
    # ========================================
    # STEP 7: 모델별 최적 스케일링
    # ========================================
    
    X_processed = X.copy()
    
    if model_type == 'tree':
        # Tree 모델: 스케일링 없음 -> Tree 모델 특성
        print(f"\n  Tree 모델: 스케일링 없음 (원본 유지)")
        # 모든 Boolean을 int로 변환
        bool_cols = X_processed.select_dtypes(include='bool').columns
        for col in bool_cols:
            X_processed[col] = X_processed[col].astype(int)
            
    elif model_type == 'linear':
        # 선형 모델: 연속형 변수만 StandardScaler -> 변수 간 스케일 차이, 스케일링 안 하면 데이터 왜곡 가능성 높음
        print(f"\n  Linear 모델: 선택적 StandardScaler")
        
        # Boolean을 int로 변환
        bool_cols = X_processed.select_dtypes(include='bool').columns
        for col in bool_cols:
            X_processed[col] = X_processed[col].astype(int)
        
        # 연속형 변수만 스케일링
        continuous_features = feature_groups['환경정보'] + \
                            feature_groups['생리반응정보'] + \
                            feature_groups['생리활성정보'] + \
                            ['stress_index', 'energy_efficiency', 'dissipation_ratio']
        
        # TChl 제거 확인 -> 다중공산성 문제 
        continuous_features = [f for f in continuous_features if f in X_processed.columns]
        
        scaler = StandardScaler()
        X_processed[continuous_features] = scaler.fit_transform(X_processed[continuous_features])
        
        print(f"    - 연속형 {len(continuous_features)}개 변수 스케일링")
        print(f"    - Binary/Category {len(X_processed.columns) - len(continuous_features)}개 유지")
        
    elif model_type == 'nn':
        # 신경망: 전체 MinMaxScaler (0~1) -> 모든 값 0~1범위 = 활성화 최적화, Gradiant 안전성, 학습 속도 향상
        print(f"\n  Neural Network: MinMaxScaler (0~1)")
        
        # Boolean을 int로 변환 
        bool_cols = X_processed.select_dtypes(include='bool').columns
        for col in bool_cols:
            X_processed[col] = X_processed[col].astype(int)
        
        scaler = MinMaxScaler()
        X_processed = pd.DataFrame(
            scaler.fit_transform(X_processed),
            columns=X_processed.columns,
            index=X_processed.index
        )
        
    print(f"\n  최종 shape: {X_processed.shape}")
    print(f"  데이터 타입: {X_processed.dtypes.value_counts().to_dict()}")
    
    return X_processed, y, scenario_mapping, feature_groups

# %% [markdown]
# ### 시나리오별 분석

# %%
def scenario_analysis(X, y, scenario_mapping, feature_groups):
    """
    공모전 요구사항: 시나리오별 상관관계 및 핵심인자 도출
    """
    
    results = {}
    
    for scenario in ['SSP1', 'SSP3', 'SSP5']:
        print(f"\n{scenario} 분석:")
        
        # 시나리오별 데이터 분리
        scenario_mask = scenario_mapping == scenario
        X_scenario = X[scenario_mask]
        y_scenario = y[scenario_mask]
        
        # 1. 데이터 개수
        print(f"  데이터 수: {X_scenario.shape[0]}개")
        
        # 2. 환경 조건 평균
        env_features = feature_groups['환경정보']
        if 'CO2ppm' in X_scenario.columns:
            print(f"  평균 CO2: {X_scenario['CO2ppm'].mean():.0f} ppm")
            print(f"  평균 온도: {X_scenario['Temp'].mean():.1f}°C")
            print(f"  평균 VPD: {X_scenario['VPD'].mean():.2f} kPa")
        
        # 3. 타겟 변수 평균
        print(f"  Leaf_TPC: {y_scenario['Leaf_TPC'].mean():.2f}")
        print(f"  Root_TPC: {y_scenario['Root_TPC'].mean():.2f}")
        
        # 4. 핵심인자 준비 (Feature Importance용)
        results[scenario] = {
            'X': X_scenario,
            'y': y_scenario,
            'n_samples': len(X_scenario)
        }
    
    return results

# %%
# 1. 데이터 로드
df = pd.read_csv('df_merged.csv')

# %%
# 2. 모델별 전처리
# Tree 모델 (XGBoost, RandomForest)
X_tree, y, scenario, groups = improved_preprocessing_final(df, 'tree')
# Out:
#   TChl 제거 완료 (Chl_a + Chl_b와 중복)
#
#   Tree 모델: 스케일링 없음 (원본 유지)
#
#   최종 shape: (405, 38)
#   데이터 타입: {dtype('float64'): 20, dtype('int64'): 18}

# %%
# Linear 모델 (Lasso, Ridge)  
X_linear, y, scenario, groups = improved_preprocessing_final(df, 'linear')
# Out:
#   TChl 제거 완료 (Chl_a + Chl_b와 중복)
#
#   Linear 모델: 선택적 StandardScaler
#     - 연속형 21개 변수 스케일링
#     - Binary/Category 17개 유지
#
#   최종 shape: (405, 38)
#   데이터 타입: {dtype('float64'): 21, dtype('int64'): 17}

# %%
#  Neural Network
X_nn, y, scenario, groups = improved_preprocessing_final(df, 'nn')
# Out:
#   TChl 제거 완료 (Chl_a + Chl_b와 중복)
#
#   Neural Network: MinMaxScaler (0~1)
#
#   최종 shape: (405, 38)
#   데이터 타입: {dtype('float64'): 38}

# %%
# 3. 시나리오별 분석 (공모전 요구사항)
scenario_results = scenario_analysis(X_tree, y, scenario, groups)
# Out:
# SSP1 분석:
#   데이터 수: 135개
#   평균 CO2: 428 ppm
#   평균 온도: 22.9°C
#   평균 VPD: 2.17 kPa
#   Leaf_TPC: 7.48
#   Root_TPC: 5.11
#
# SSP3 분석:
#   데이터 수: 135개
#   평균 CO2: 918 ppm
#   평균 온도: 24.7°C
#   평균 VPD: 2.40 kPa
#   Leaf_TPC: 7.80
#   Root_TPC: 5.15
#
# SSP5 분석:
#   데이터 수: 135개
#   평균 CO2: 1174 ppm
#   평균 온도: 25.5°C
#   평균 VPD: 2.51 kPa
#   Leaf_TPC: 7.84
#   Root_TPC: 5.17

# %%
# 4. 저장
X_tree.to_csv('X_preprocessed_tree.csv', index=False)
X_linear.to_csv('X_preprocessed_linear.csv', index=False)
X_nn.to_csv('X_preprocessed_nn.csv', index=False)
y.to_csv('y_targets.csv', index=False)

# %%
# 시나리오 정보도 저장 (중요!)
pd.DataFrame({'scenario': scenario}).to_csv('scenario_info.csv', index=False)
